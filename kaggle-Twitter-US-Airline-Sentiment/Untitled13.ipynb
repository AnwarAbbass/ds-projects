# %%
import sklearn
import matplotlib.pyplot as plt 
import pandas as pd
import numpy
import nltk
from wordcloud import WordCloud,STOPWORDS
import re

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
tweet=pd.read_csv('Tweets.csv')
tweet.head()
# Out:
#   Selected  ...                                             Author
# 0   No Yes  ...  @clickgaza @_Gusttavo_Tello @richsad @RikardoC...
# 1    class  ...                                               meta
# 2       No  ...                                    @Lynn_Claessens
# 3       No  ...                                   @bruce_southside
# 4       No  ...                                       @BBCTalkback
#
# [5 rows x 19 columns]

# %%
tweet.drop([0,1],axis=0,inplace=True)

# %%
tweet.columns
# Out:
# Index(['Selected', 'Content', 'Date', 'Language', 'Location',
#        'Number of Likes', 'Number of Retweets', 'In Reply To', 'Author Name',
#        'Author Description', 'Author Statuses Count',
#        'Author Favourites Count', 'Author Friends Count',
#        'Author Followers Count', 'Author Listed Count', 'Author Verified',
#        'Longitude', 'Latitude', 'Author'],
#       dtype='object')

# %%
tweet.rename(columns={'Selected':'class'},inplace=True)

# %%
tweet.isna().sum()
# Out:
# class                        0
# Content                      0
# Date                         0
# Language                     0
# Location                   197
# Number of Likes              0
# Number of Retweets           0
# In Reply To                178
# Author Name                  0
# Author Description          10
# Author Statuses Count        0
# Author Favourites Count      0
# Author Friends Count         0
# Author Followers Count       0
# Author Listed Count          0
# Author Verified              0
# Longitude                  200
# Latitude                   200
# Author                       0
# dtype: int64

# %%
tweet.drop(['Location','Author',
            'Author Name','In Reply To',
            'Author Description',
            'Author Statuses Count',
            'Author Favourites Count',
            'Author Friends Count',
            'Author Followers Count',
            'Author Listed Count',
            'Author Verified',
            'Longitude',
            'Latitude'],axis=1,inplace=True)

# %%
tweet.head()
# Out:
#   class  ... Number of Retweets
# 2    No  ...                0.0
# 3    No  ...                0.0
# 4    No  ...                0.0
# 5    No  ...                0.0
# 6    No  ...                0.0
#
# [5 rows x 6 columns]

# %%
tweet['Language'].value_counts()
tweet['class'].value_counts()

# %%
tweet.drop(['Language','class'],axis=1,inplace=True)

# %%
cloud= WordCloud(background_color='white',random_state=111).generate(str(tweet['Content']))
fig= plt.figure(figsize=(10,10))
plt.axis('off')
plt.imshow(cloud)

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
